# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepika4C69/Heart-Disease-Predection/blob/main/Heart_Disease_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras

# %%
from keras.models import Sequential
models = Sequential()

# %%
from keras.layers import Dense

# %%
import pandas as pd
dt = pd.read_csv('/content/dataset_heart.csv')
dt.head()
# Out:
#    age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0   70     1                4                     130                322
# 1   67     0                3                     115                564
# 2   57     1                2                     124                261
# 3   64     1                4                     128                263
# 4   74     0                2                     120                269
#
#    fasting blood sugar  resting electrocardiographic results  max heart rate  \
# 0                    0                                     2             109
# 1                    0                                     2             160
# 2                    0                                     0             141
# 3                    0                                     0             105
# 4                    0                                     2             121
#
#    exercise induced angina  oldpeak  ST segment  major vessels  thal  \
# 0                        0      2.4           2              3     3
# 1                        0      1.6           2              0     7
# 2                        0      0.3           1              0     7
# 3                        1      0.2           2              1     7
# 4                        1      0.2           1              1     3
#
#    heart disease
# 0              2
# 1              1
# 2              2
# 3              1
# 4              1

# %%
dt.corr()
# Out:
#                                            age      sex   chest pain type  \
# age                                   1.000000 -0.094401         0.096920
# sex                                  -0.094401  1.000000         0.034636
# chest pain type                       0.096920  0.034636         1.000000
# resting blood pressure                0.273053 -0.062693        -0.043196
# serum cholestoral                     0.220056 -0.201647         0.090465
# fasting blood sugar                   0.123458  0.042140        -0.098537
# resting electrocardiographic results  0.128171  0.039253         0.074325
# max heart rate                       -0.402215 -0.076101        -0.317682
# exercise induced angina               0.098297  0.180022         0.353160
# oldpeak                               0.194234  0.097412         0.167244
# ST segment                            0.159774  0.050545         0.136900
# major vessels                         0.356081  0.086830         0.225890
# thal                                  0.106100  0.391046         0.262659
# heart disease                         0.212322  0.297721         0.417436
#
#                                       resting blood pressure  \
# age                                                 0.273053
# sex                                                -0.062693
# chest pain type                                    -0.043196
# resting blood pressure                              1.000000
# serum cholestoral                                   0.173019
# fasting blood sugar                                 0.155681
# resting electrocardiographic results                0.116157
# max heart rate                                     -0.039136
# exercise induced angina                             0.082793
# oldpeak                                             0.222800
# ST segment                                          0.142472
# major vessels                                       0.085697
# thal                                                0.132045
# heart disease                                       0.155383
#
#                                       serum cholestoral  fasting blood sugar  \
# age                                            0.220056             0.123458
# sex                                           -0.201647             0.042140
# chest pain type                                0.090465            -0.098537
# resting blood pressure                         0.173019             0.155681
# serum cholestoral                              1.000000             0.025186
# fasting blood sugar                            0.025186             1.000000
# resting electrocardiographic results           0.167652             0.053499
# max heart rate                                -0.018739             0.022494
# exercise induced angina                        0.078243            -0.004107
# oldpeak                                        0.027709            -0.025538
# ST segment                                    -0.005755             0.044076
# major vessels                                  0.126541             0.123774
# thal                                           0.028836             0.049237
# heart disease                                  0.118021            -0.016319
#
#                                       resting electrocardiographic results  \
# age                                                               0.128171
# sex                                                               0.039253
# chest pain type                                                   0.074325
# resting blood pressure                                            0.116157
# serum cholestoral                                                 0.167652
# fasting blood sugar                                               0.053499
# resting electrocardiographic results                              1.000000
# max heart rate                                                   -0.074628
# exercise induced angina                                           0.095098
# oldpeak                                                           0.120034
# ST segment                                                        0.160614
# major vessels                                                     0.114368
# thal                                                              0.007337
# heart disease                                                     0.182091
#
#                                       max heart rate  exercise induced angina  \
# age                                        -0.402215                 0.098297
# sex                                        -0.076101                 0.180022
# chest pain type                            -0.317682                 0.353160
# resting blood pressure                     -0.039136                 0.082793
# serum cholestoral                          -0.018739                 0.078243
# fasting blood sugar                         0.022494                -0.004107
# resting electrocardiographic results       -0.074628                 0.095098
# max heart rate                              1.000000                -0.380719
# exercise induced angina                    -0.380719                 1.000000
# oldpeak                                    -0.349045                 0.274672
# ST segment                                 -0.386847                 0.255908
# major vessels                              -0.265333                 0.153347
# thal                                       -0.253397                 0.321449
# heart disease                              -0.418514                 0.419303
#
#                                        oldpeak  ST segment  major vessels  \
# age                                   0.194234    0.159774       0.356081
# sex                                   0.097412    0.050545       0.086830
# chest pain type                       0.167244    0.136900       0.225890
# resting blood pressure                0.222800    0.142472       0.085697
# serum cholestoral                     0.027709   -0.005755       0.126541
# fasting blood sugar                  -0.025538    0.044076       0.123774
# resting electrocardiographic results  0.120034    0.160614       0.114368
# max heart rate                       -0.349045   -0.386847      -0.265333
# exercise induced angina               0.274672    0.255908       0.153347
# oldpeak                               1.000000    0.609712       0.255005
# ST segment                            0.609712    1.000000       0.109498
# major vessels                         0.255005    0.109498       1.000000
# thal                                  0.324333    0.283678       0.255648
# heart disease                         0.417967    0.337616       0.455336
#
#                                           thal  heart disease
# age                                   0.106100       0.212322
# sex                                   0.391046       0.297721
# chest pain type                       0.262659       0.417436
# resting blood pressure                0.132045       0.155383
# serum cholestoral                     0.028836       0.118021
# fasting blood sugar                   0.049237      -0.016319
# resting electrocardiographic results  0.007337       0.182091
# max heart rate                       -0.253397      -0.418514
# exercise induced angina               0.321449       0.419303
# oldpeak                               0.324333       0.417967
# ST segment                            0.283678       0.337616
# major vessels                         0.255648       0.455336
# thal                                  1.000000       0.525020
# heart disease                         0.525020       1.000000

# %%
print(dt.columns)

columns_to_drop = ['chol', 'fbs']
existing_columns_to_drop = [col for col in columns_to_drop if col in dt.columns]

if existing_columns_to_drop:
    dt = dt.drop(existing_columns_to_drop, axis=1)
    print("Columns dropped successfully.")
else:
    print("Columns 'chol' and 'fbs' not found in the DataFrame.")
# Out:
# Index(['age', 'sex ', 'chest pain type', 'resting blood pressure',
#        'serum cholestoral', 'fasting blood sugar',
#        'resting electrocardiographic results', 'max heart rate',
#        'exercise induced angina', 'oldpeak', 'ST segment', 'major vessels',
#        'thal', 'heart disease'],
#       dtype='object')
# Columns 'chol' and 'fbs' not found in the DataFrame.

# %%
dt.tail(2)
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
#      fasting blood sugar  resting electrocardiographic results  \
# 268                    0                                     0
# 269                    0                                     2
#
#      max heart rate  exercise induced angina  oldpeak  ST segment  \
# 268             148                        0      0.4           2
# 269             108                        1      1.5           2
#
#      major vessels  thal  heart disease
# 268              0     6              1
# 269              3     3              2

# %%
x = dt.iloc[:,0:11]
y = dt['heart disease']

# %%
x
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0     70     1                4                     130                322
# 1     67     0                3                     115                564
# 2     57     1                2                     124                261
# 3     64     1                4                     128                263
# 4     74     0                2                     120                269
# ..   ...   ...              ...                     ...                ...
# 265   52     1                3                     172                199
# 266   44     1                2                     120                263
# 267   56     0                2                     140                294
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
#      fasting blood sugar  resting electrocardiographic results  \
# 0                      0                                     2
# 1                      0                                     2
# 2                      0                                     0
# 3                      0                                     0
# 4                      0                                     2
# ..                   ...                                   ...
# 265                    1                                     0
# 266                    0                                     0
# 267                    0                                     2
# 268                    0                                     0
# 269                    0                                     2
#
#      max heart rate  exercise induced angina  oldpeak  ST segment
# 0               109                        0      2.4           2
# 1               160                        0      1.6           2
# 2               141                        0      0.3           1
# 3               105                        1      0.2           2
# 4               121                        1      0.2           1
# ..              ...                      ...      ...         ...
# 265             162                        0      0.5           1
# 266             173                        0      0.0           1
# 267             153                        0      1.3           2
# 268             148                        0      0.4           2
# 269             108                        1      1.5           2
#
# [270 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
print(x.shape,y.shape,x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (270, 11) (270,) (202, 11) (68, 11) (202,) (68,)

# %%
models.add(Dense(units=10,activation='relu'))

# %%
models.add(Dense(units=7,activation='relu'))

# %%
models.add(Dense(units=1,activation='sigmoid'))

# %%
models.add(Dense(units=11,activation='relu'))
models.add(Dense(units=5,activation='relu'))
models.add(Dense(units=1,activation='sigmoid'))
models.build(input_shape=(None,11))

# %%
models.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 10)             │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 7)              │            77 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 11)             │            22 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 5)              │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 7)              │            77 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 11)             │            22 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 5)              │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 11)             │            66 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 5)              │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 646 (2.52 KB)
#  Trainable params: 646 (2.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
models.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
models.fit(x_train,y_train,epochs=50,batch_size=8)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5563 - loss: -3777.3999
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5464 - loss: -4228.0591
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5880 - loss: -4215.4658
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5489 - loss: -5026.6089
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5596 - loss: -5354.9136
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5479 - loss: -5987.2490
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5788 - loss: -6067.4648
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5388 - loss: -7203.5557
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5422 - loss: -7759.8525
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5358 - loss: -8484.4541
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5272 - loss: -9313.9180
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5455 - loss: -9669.9766
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5174 - loss: -11045.7891
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5784 - loss: -10367.4453
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5233 - loss: -12534.1240
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5299 - loss: -13281.9775
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5649 - loss: -13176.7871
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5112 - loss: -15774.4521
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5294 - loss: -16229.1768
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5268 - loss: -17426.8652
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5806 - loss: -16509.3789
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5899 - loss: -17206.0312
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5359 - loss: -20716.8770
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5701 - loss: -20442.2637
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5945 - loss: -20504.5234
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5886 - loss: -22075.4727
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5170 - loss: -27437.4746
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5220 - loss: -28788.4355
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5748 - loss: -27111.2539
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5452 - loss: -30627.2988
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5766 - loss: -30150.9590
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5591 - loss: -33096.7031
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5347 - loss: -36822.0117
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5897 - loss: -34279.7617
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5259 - loss: -41662.1992
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5545 - loss: -41261.5195
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5037 - loss: -48244.4023
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5337 - loss: -47710.0781
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5425 - loss: -49196.5391
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5827 - loss: -47137.8672
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5493 - loss: -53355.3438
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5463 - loss: -56263.3438
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5737 - loss: -55388.8281
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5284 - loss: -64146.7539
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5778 - loss: -60150.9219
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5305 - loss: -69891.3594
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5223 - loss: -74362.7891
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5095 - loss: -79757.5078
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5621 - loss: -74419.5312
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5700 - loss: -76220.0156

# %%
y_pred = models.predict(x_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step

# %%
y_pred = (y_pred > 0.5).astype(int)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.5735294117647058

# %%
models.save('heart.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
x_train
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 59    62     1                2                     120                281
# 212   43     0                3                     122                213
# 158   56     1                1                     120                193
# 191   70     1                4                     145                174
# 84    57     1                4                     110                201
# ..   ...   ...              ...                     ...                ...
# 138   34     0                2                     118                210
# 229   52     1                1                     118                186
# 119   56     1                4                     130                283
# 8     60     1                4                     140                293
# 157   45     1                2                     128                308
#
#      fasting blood sugar  resting electrocardiographic results  \
# 59                     0                                     2
# 212                    0                                     0
# 158                    0                                     2
# 191                    0                                     0
# 84                     0                                     0
# ..                   ...                                   ...
# 138                    0                                     0
# 229                    0                                     2
# 119                    1                                     2
# 8                      0                                     2
# 157                    0                                     2
#
#      max heart rate  exercise induced angina  oldpeak  ST segment
# 59              103                        0      1.4           2
# 212             165                        0      0.2           2
# 158             162                        0      1.9           2
# 191             125                        1      2.6           3
# 84              126                        1      1.5           2
# ..              ...                      ...      ...         ...
# 138             192                        0      0.7           1
# 229             190                        0      0.0           2
# 119             103                        1      1.6           3
# 8               170                        0      1.2           2
# 157             170                        0      0.0           1
#
# [202 rows x 11 columns]

# %%
x_train.columns
# Out:
# Index(['age', 'sex ', 'chest pain type', 'resting blood pressure',
#        'serum cholestoral', 'fasting blood sugar',
#        'resting electrocardiographic results', 'max heart rate',
#        'exercise induced angina', 'oldpeak', 'ST segment'],
#       dtype='object')
