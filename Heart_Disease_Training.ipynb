# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepika4C69/Heart-Disease-Predection/blob/main/Heart_Disease_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras

# %%
from keras.models import Sequential
models = Sequential()

# %%
from keras.layers import Dense

# %%
import pandas as pd
dt = pd.read_csv('/content/dataset_heart.csv')
dt.head()
# Out:
#    age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0   70     1                4                     130                322
# 1   67     0                3                     115                564
# 2   57     1                2                     124                261
# 3   64     1                4                     128                263
# 4   74     0                2                     120                269
#
#    fasting blood sugar  resting electrocardiographic results  max heart rate  \
# 0                    0                                     2             109
# 1                    0                                     2             160
# 2                    0                                     0             141
# 3                    0                                     0             105
# 4                    0                                     2             121
#
#    exercise induced angina  oldpeak  ST segment  major vessels  thal  \
# 0                        0      2.4           2              3     3
# 1                        0      1.6           2              0     7
# 2                        0      0.3           1              0     7
# 3                        1      0.2           2              1     7
# 4                        1      0.2           1              1     3
#
#    heart disease
# 0              2
# 1              1
# 2              2
# 3              1
# 4              1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sex '].plot(kind='hist', bins=20, title='sex ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['chest pain type'].plot(kind='hist', bins=20, title='chest pain type')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['resting blood pressure'].plot(kind='hist', bins=20, title='resting blood pressure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='age', y='sex ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='sex ', y='chest pain type', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='chest pain type', y='resting blood pressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='resting blood pressure', y='serum cholestoral', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['fasting blood sugar']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('fasting blood sugar', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('fasting blood sugar')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['fasting blood sugar']
#   ys = series['sex ']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('fasting blood sugar', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('fasting blood sugar')
# _ = plt.ylabel('sex ')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['fasting blood sugar']
#   ys = series['chest pain type']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('fasting blood sugar', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('fasting blood sugar')
# _ = plt.ylabel('chest pain type')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['fasting blood sugar']
#   ys = series['resting blood pressure']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('fasting blood sugar', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('fasting blood sugar')
# _ = plt.ylabel('resting blood pressure')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['sex '].plot(kind='line', figsize=(8, 4), title='sex ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['chest pain type'].plot(kind='line', figsize=(8, 4), title='chest pain type')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['resting blood pressure'].plot(kind='line', figsize=(8, 4), title='resting blood pressure')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
dt.corr()
# Out:
#                                            age      sex   chest pain type  \
# age                                   1.000000 -0.094401         0.096920
# sex                                  -0.094401  1.000000         0.034636
# chest pain type                       0.096920  0.034636         1.000000
# resting blood pressure                0.273053 -0.062693        -0.043196
# serum cholestoral                     0.220056 -0.201647         0.090465
# fasting blood sugar                   0.123458  0.042140        -0.098537
# resting electrocardiographic results  0.128171  0.039253         0.074325
# max heart rate                       -0.402215 -0.076101        -0.317682
# exercise induced angina               0.098297  0.180022         0.353160
# oldpeak                               0.194234  0.097412         0.167244
# ST segment                            0.159774  0.050545         0.136900
# major vessels                         0.356081  0.086830         0.225890
# thal                                  0.106100  0.391046         0.262659
# heart disease                         0.212322  0.297721         0.417436
#
#                                       resting blood pressure  \
# age                                                 0.273053
# sex                                                -0.062693
# chest pain type                                    -0.043196
# resting blood pressure                              1.000000
# serum cholestoral                                   0.173019
# fasting blood sugar                                 0.155681
# resting electrocardiographic results                0.116157
# max heart rate                                     -0.039136
# exercise induced angina                             0.082793
# oldpeak                                             0.222800
# ST segment                                          0.142472
# major vessels                                       0.085697
# thal                                                0.132045
# heart disease                                       0.155383
#
#                                       serum cholestoral  fasting blood sugar  \
# age                                            0.220056             0.123458
# sex                                           -0.201647             0.042140
# chest pain type                                0.090465            -0.098537
# resting blood pressure                         0.173019             0.155681
# serum cholestoral                              1.000000             0.025186
# fasting blood sugar                            0.025186             1.000000
# resting electrocardiographic results           0.167652             0.053499
# max heart rate                                -0.018739             0.022494
# exercise induced angina                        0.078243            -0.004107
# oldpeak                                        0.027709            -0.025538
# ST segment                                    -0.005755             0.044076
# major vessels                                  0.126541             0.123774
# thal                                           0.028836             0.049237
# heart disease                                  0.118021            -0.016319
#
#                                       resting electrocardiographic results  \
# age                                                               0.128171
# sex                                                               0.039253
# chest pain type                                                   0.074325
# resting blood pressure                                            0.116157
# serum cholestoral                                                 0.167652
# fasting blood sugar                                               0.053499
# resting electrocardiographic results                              1.000000
# max heart rate                                                   -0.074628
# exercise induced angina                                           0.095098
# oldpeak                                                           0.120034
# ST segment                                                        0.160614
# major vessels                                                     0.114368
# thal                                                              0.007337
# heart disease                                                     0.182091
#
#                                       max heart rate  exercise induced angina  \
# age                                        -0.402215                 0.098297
# sex                                        -0.076101                 0.180022
# chest pain type                            -0.317682                 0.353160
# resting blood pressure                     -0.039136                 0.082793
# serum cholestoral                          -0.018739                 0.078243
# fasting blood sugar                         0.022494                -0.004107
# resting electrocardiographic results       -0.074628                 0.095098
# max heart rate                              1.000000                -0.380719
# exercise induced angina                    -0.380719                 1.000000
# oldpeak                                    -0.349045                 0.274672
# ST segment                                 -0.386847                 0.255908
# major vessels                              -0.265333                 0.153347
# thal                                       -0.253397                 0.321449
# heart disease                              -0.418514                 0.419303
#
#                                        oldpeak  ST segment  major vessels  \
# age                                   0.194234    0.159774       0.356081
# sex                                   0.097412    0.050545       0.086830
# chest pain type                       0.167244    0.136900       0.225890
# resting blood pressure                0.222800    0.142472       0.085697
# serum cholestoral                     0.027709   -0.005755       0.126541
# fasting blood sugar                  -0.025538    0.044076       0.123774
# resting electrocardiographic results  0.120034    0.160614       0.114368
# max heart rate                       -0.349045   -0.386847      -0.265333
# exercise induced angina               0.274672    0.255908       0.153347
# oldpeak                               1.000000    0.609712       0.255005
# ST segment                            0.609712    1.000000       0.109498
# major vessels                         0.255005    0.109498       1.000000
# thal                                  0.324333    0.283678       0.255648
# heart disease                         0.417967    0.337616       0.455336
#
#                                           thal  heart disease
# age                                   0.106100       0.212322
# sex                                   0.391046       0.297721
# chest pain type                       0.262659       0.417436
# resting blood pressure                0.132045       0.155383
# serum cholestoral                     0.028836       0.118021
# fasting blood sugar                   0.049237      -0.016319
# resting electrocardiographic results  0.007337       0.182091
# max heart rate                       -0.253397      -0.418514
# exercise induced angina               0.321449       0.419303
# oldpeak                               0.324333       0.417967
# ST segment                            0.283678       0.337616
# major vessels                         0.255648       0.455336
# thal                                  1.000000       0.525020
# heart disease                         0.525020       1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['sex '].plot(kind='hist', bins=20, title='sex ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['chest pain type'].plot(kind='hist', bins=20, title='chest pain type')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['resting blood pressure'].plot(kind='hist', bins=20, title='resting blood pressure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20.plot(kind='scatter', x='age', y='sex ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21.plot(kind='scatter', x='sex ', y='chest pain type', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22.plot(kind='scatter', x='chest pain type', y='resting blood pressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23.plot(kind='scatter', x='resting blood pressure', y='serum cholestoral', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_24['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['sex '].plot(kind='line', figsize=(8, 4), title='sex ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['chest pain type'].plot(kind='line', figsize=(8, 4), title='chest pain type')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['resting blood pressure'].plot(kind='line', figsize=(8, 4), title='resting blood pressure')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
print(dt.columns)

columns_to_drop = ['chol', 'fbs']
existing_columns_to_drop = [col for col in columns_to_drop if col in dt.columns]

if existing_columns_to_drop:
    dt = dt.drop(existing_columns_to_drop, axis=1)
    print("Columns dropped successfully.")
else:
    print("Columns 'chol' and 'fbs' not found in the DataFrame.")
# Out:
# Index(['age', 'sex ', 'chest pain type', 'resting blood pressure',
#        'serum cholestoral', 'fasting blood sugar',
#        'resting electrocardiographic results', 'max heart rate',
#        'exercise induced angina', 'oldpeak', 'ST segment', 'major vessels',
#        'thal', 'heart disease'],
#       dtype='object')
# Columns 'chol' and 'fbs' not found in the DataFrame.

# %%
dt.tail(2)
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
#      fasting blood sugar  resting electrocardiographic results  \
# 268                    0                                     0
# 269                    0                                     2
#
#      max heart rate  exercise induced angina  oldpeak  ST segment  \
# 268             148                        0      0.4           2
# 269             108                        1      1.5           2
#
#      major vessels  thal  heart disease
# 268              0     6              1
# 269              3     3              2

# %%
x = dt.iloc[:,0:11]
y = dt['heart disease']

# %%
x
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0     70     1                4                     130                322
# 1     67     0                3                     115                564
# 2     57     1                2                     124                261
# 3     64     1                4                     128                263
# 4     74     0                2                     120                269
# ..   ...   ...              ...                     ...                ...
# 265   52     1                3                     172                199
# 266   44     1                2                     120                263
# 267   56     0                2                     140                294
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
#      fasting blood sugar  resting electrocardiographic results  \
# 0                      0                                     2
# 1                      0                                     2
# 2                      0                                     0
# 3                      0                                     0
# 4                      0                                     2
# ..                   ...                                   ...
# 265                    1                                     0
# 266                    0                                     0
# 267                    0                                     2
# 268                    0                                     0
# 269                    0                                     2
#
#      max heart rate  exercise induced angina  oldpeak  ST segment
# 0               109                        0      2.4           2
# 1               160                        0      1.6           2
# 2               141                        0      0.3           1
# 3               105                        1      0.2           2
# 4               121                        1      0.2           1
# ..              ...                      ...      ...         ...
# 265             162                        0      0.5           1
# 266             173                        0      0.0           1
# 267             153                        0      1.3           2
# 268             148                        0      0.4           2
# 269             108                        1      1.5           2
#
# [270 rows x 11 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x['sex '].plot(kind='hist', bins=20, title='sex ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x['chest pain type'].plot(kind='hist', bins=20, title='chest pain type')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x['resting blood pressure'].plot(kind='hist', bins=20, title='resting blood pressure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x.plot(kind='scatter', x='age', y='sex ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x.plot(kind='scatter', x='sex ', y='chest pain type', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x.plot(kind='scatter', x='chest pain type', y='resting blood pressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x.plot(kind='scatter', x='resting blood pressure', y='serum cholestoral', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x['sex '].plot(kind='line', figsize=(8, 4), title='sex ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x['chest pain type'].plot(kind='line', figsize=(8, 4), title='chest pain type')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x['resting blood pressure'].plot(kind='line', figsize=(8, 4), title='resting blood pressure')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
print(x.shape,y.shape,x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (270, 11) (270,) (202, 11) (68, 11) (202,) (68,)

# %%
models.add(Dense(units=10,activation='relu'))

# %%
models.add(Dense(units=7,activation='relu'))

# %%
models.add(Dense(units=1,activation='sigmoid'))

# %%
models.add(Dense(units=11,activation='relu'))
models.add(Dense(units=5,activation='relu'))
models.add(Dense(units=1,activation='sigmoid'))
models.build(input_shape=(None,11))

# %%
models.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                │ (None, 10)             │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 7)              │            77 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 11)             │            22 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 5)              │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 293 (1.14 KB)
#  Trainable params: 293 (1.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
models.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
models.fit(x_train,y_train,epochs=50,batch_size=8)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5802 - loss: 0.6533
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5248 - loss: 0.4317
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6233 - loss: -0.0695
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5709 - loss: -0.8076
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5360 - loss: -1.3477
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5325 - loss: -2.0493
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5297 - loss: -3.2640
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6188 - loss: -3.4348
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5561 - loss: -4.9919
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5729 - loss: -5.9085
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5602 - loss: -7.2802
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5588 - loss: -8.7064
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5359 - loss: -10.8145
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5474 - loss: -12.3894
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5823 - loss: -13.3512
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5573 - loss: -16.3425
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5793 - loss: -17.8444
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5633 - loss: -21.2169
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5634 - loss: -24.1972
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5575 - loss: -27.7280
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5992 - loss: -28.3796
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5447 - loss: -35.9049
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5157 - loss: -42.4866
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5527 - loss: -43.6747
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5946 - loss: -43.8844
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4995 - loss: -59.4750
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5656 - loss: -56.8745
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5991 - loss: -57.6057
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5674 - loss: -68.0330
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5743 - loss: -73.3353
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5232 - loss: -89.2519
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5482 - loss: -91.8190
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5900 - loss: -90.3256
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4988 - loss: -119.0296
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5233 - loss: -122.3774
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6216 - loss: -104.6440
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5957 - loss: -119.9607
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5906 - loss: -130.3457
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5221 - loss: -162.6918
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5864 - loss: -150.8558
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5595 - loss: -171.0503
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5605 - loss: -181.7975
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5997 - loss: -176.0501
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4933 - loss: -235.6749
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5394 - loss: -227.6669
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5896 - loss: -214.8585
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5774 - loss: -234.1110
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5639 - loss: -255.5271
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4957 - loss: -311.5154
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6140 - loss: -252.1012

# %%
y_pred = models.predict(x_test)
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d1883f1ef20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d1883f1ef20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %%
y_pred = (y_pred > 0.5).astype(int)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.5294117647058824

# %%
models.save('heart.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
x_train
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 181   56     0                4                     134                409
# 161   62     0                4                     150                244
# 107   60     0                4                     150                258
# 6     56     1                3                     130                256
# 186   56     1                4                     132                184
# ..   ...   ...              ...                     ...                ...
# 113   54     0                3                     135                304
# 149   41     0                3                     112                268
# 101   67     1                4                     120                237
# 46    49     1                3                     118                149
# 192   54     1                2                     108                309
#
#      fasting blood sugar  resting electrocardiographic results  \
# 181                    0                                     2
# 161                    0                                     0
# 107                    0                                     2
# 6                      1                                     2
# 186                    0                                     2
# ..                   ...                                   ...
# 113                    1                                     0
# 149                    0                                     2
# 101                    0                                     0
# 46                     0                                     2
# 192                    0                                     0
#
#      max heart rate  exercise induced angina  oldpeak  ST segment
# 181             150                        1      1.9           2
# 161             154                        1      1.4           2
# 107             157                        0      2.6           2
# 6               142                        1      0.6           2
# 186             105                        1      2.1           2
# ..              ...                      ...      ...         ...
# 113             170                        0      0.0           1
# 149             172                        1      0.0           1
# 101              71                        0      1.0           2
# 46              126                        0      0.8           1
# 192             156                        0      0.0           1
#
# [202 rows x 11 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_train['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_train['sex '].plot(kind='hist', bins=20, title='sex ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_train['chest pain type'].plot(kind='hist', bins=20, title='chest pain type')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_train['resting blood pressure'].plot(kind='hist', bins=20, title='resting blood pressure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_train.plot(kind='scatter', x='age', y='sex ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_train.plot(kind='scatter', x='sex ', y='chest pain type', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_train.plot(kind='scatter', x='chest pain type', y='resting blood pressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_train.plot(kind='scatter', x='resting blood pressure', y='serum cholestoral', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_train['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x_train['sex '].plot(kind='line', figsize=(8, 4), title='sex ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x_train['chest pain type'].plot(kind='line', figsize=(8, 4), title='chest pain type')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x_train['resting blood pressure'].plot(kind='line', figsize=(8, 4), title='resting blood pressure')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
x_train.columns
# Out:
# Index(['age', 'sex ', 'chest pain type', 'resting blood pressure',
#        'serum cholestoral', 'fasting blood sugar',
#        'resting electrocardiographic results', 'max heart rate',
#        'exercise induced angina', 'oldpeak', 'ST segment'],
#       dtype='object')
